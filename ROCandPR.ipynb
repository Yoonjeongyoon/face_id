# %%
import numpy as np

data = np.load("adaface_ms1mv2_ir50_confusion_metrics.npz")
tp = data["tp"]  
tn = data["tn"]
fp = data["fp"]
fn = data["fn"]

eps = 1e-10  

tpr = np.mean(tp / (tp + fn + eps), axis=0)  
fpr = np.mean(fp / (fp + tn + eps), axis=0)

precision = np.mean(tp / (tp + fp + eps), axis=0)
recall = np.mean(tp / (tp + fn + eps), axis=0)

# %%
import matplotlib.pyplot as plt

# ROC Curve
plt.figure()
plt.plot(fpr, tpr, label='ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate (Recall)')
plt.title('ROC Curve')
plt.grid(True)
plt.legend()
plt.show()

# %%
# PR Curve
plt.figure()
plt.plot(recall, precision, label='PR Curve', color='orange')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# 데이터 로드
data_our = np.load("topofr_ms1mv2_r200_asian_celebrity.npz")
tp_our = data_our["tp"]
tn_our = data_our["tn"]
fp_our = data_our["fp"]
fn_our = data_our["fn"]
data_LFW = np.load("topofr_ms1mv2_r200_LFW.npz")
tp_LFW = data_LFW["tp"]
tn_LFW = data_LFW["tn"]
fp_LFW = data_LFW["fp"]
fn_LFW = data_LFW["fn"]
eps = 1e-10
tpr_our = np.mean(tp_our / (tp_our + fn_our + eps), axis=0)
fpr_our = np.mean(fp_our / (fp_our + tn_our + eps), axis=0)

precision_our = np.mean(tp_our / (tp_our + fp_our + eps), axis=0)
recall_our = np.mean(tp_our / (tp_our + fn_our + eps), axis=0)

tpr_LFW = np.mean(tp_LFW / (tp_LFW + fn_LFW + eps), axis=0)
fpr_LFW = np.mean(fp_LFW / (fp_LFW + tn_LFW + eps), axis=0)

precision_LFW = np.mean(tp_LFW / (tp_LFW + fp_LFW + eps), axis=0)
recall_LFW = np.mean(tp_LFW / (tp_LFW + fn_LFW + eps), axis=0)

# 메인 PR Curve
plt.figure(figsize=(6, 5))

plt.plot(recall_our, precision_our, label='Ours', color='red', linewidth=2)
plt.plot(recall_LFW, precision_LFW, label='LFW', color='blue', linewidth=2)
plt.xlabel("Recall", fontsize=14, labelpad=10)
plt.ylabel("Precision", fontsize=14)


plt.xlim(0.95, 1.0)

plt.ylim(0.5, 1.01)

plt.grid(True, alpha=0.5)
plt.legend(loc='lower left', fontsize=14)
plt.tight_layout()
plt.savefig("figure_4.8_v1.pdf", dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# 데이터 로드
data_our = np.load("adaface_ms1mv3_ir101_asian_celebrity.npz")
tp_our = data_our["tp"]
tn_our = data_our["tn"]
fp_our = data_our["fp"]
fn_our = data_our["fn"]
data_LFW = np.load("adaface_ms1mv3_ir101_LFW.npz")
tp_LFW = data_LFW["tp"]
tn_LFW = data_LFW["tn"]
fp_LFW = data_LFW["fp"]
fn_LFW = data_LFW["fn"]
eps = 1e-10
tpr_our = np.mean(tp_our / (tp_our + fn_our + eps), axis=0)
fpr_our = np.mean(fp_our / (fp_our + tn_our + eps), axis=0)

precision_our = np.mean(tp_our / (tp_our + fp_our + eps), axis=0)
recall_our = np.mean(tp_our / (tp_our + fn_our + eps), axis=0)

tpr_LFW = np.mean(tp_LFW / (tp_LFW + fn_LFW + eps), axis=0)
fpr_LFW = np.mean(fp_LFW / (fp_LFW + tn_LFW + eps), axis=0)

precision_LFW = np.mean(tp_LFW / (tp_LFW + fp_LFW + eps), axis=0)
recall_LFW = np.mean(tp_LFW / (tp_LFW + fn_LFW + eps), axis=0)

# 메인 PR Curve
plt.figure(figsize=(6, 5))

plt.plot(recall_our, precision_our, label='Ours', color='red', linewidth=2)
plt.plot(recall_LFW, precision_LFW, label='LFW', color='blue', linewidth=2)
plt.xlabel("Recall", fontsize=14, labelpad=10)
plt.ylabel("Precision", fontsize=14)


plt.xlim(0.95, 1.0)

plt.ylim(0.5, 1.01)

plt.grid(True, alpha=0.5)
plt.legend(loc='lower left', fontsize=14)
plt.tight_layout()
plt.savefig("figure_4.5_v1.pdf", dpi=300)
plt.show()
