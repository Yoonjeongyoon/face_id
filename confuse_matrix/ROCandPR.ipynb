# %%
import numpy as np

data = np.load("adaface_ms1mv2_ir50_confusion_metrics.npz")
tp = data["tp"]  
tn = data["tn"]
fp = data["fp"]
fn = data["fn"]

eps = 1e-10  

tpr = np.mean(tp / (tp + fn + eps), axis=0)  
fpr = np.mean(fp / (fp + tn + eps), axis=0)

precision = np.mean(tp / (tp + fp + eps), axis=0)
recall = np.mean(tp / (tp + fn + eps), axis=0)

# %%
import matplotlib.pyplot as plt

# ROC Curve
plt.figure()
plt.plot(fpr, tpr, label='ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate (Recall)')
plt.title('ROC Curve')
plt.grid(True)
plt.legend()
plt.show()

# %%
# PR Curve
plt.figure()
plt.plot(recall, precision, label='PR Curve', color='orange')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.legend()
plt.show()
